# %% [markdown]
# 1. Upload test directory and ner_client.py to colab
# 2. run below command

# %%
# !pwd
# Out:
# /content

# %%
# !python -m pytest
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.10.12, pytest-7.4.4, pluggy-1.4.0
# rootdir: /content
# plugins: anyio-3.7.1
# collected 1 item
#
# test/test_ner_client.py .                                                                    [100%]
#
# ======================================== 1 passed in 0.02s =========================================
